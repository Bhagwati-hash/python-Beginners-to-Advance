# %%
# library we are going to use 
# pip install pandas
# pip install numpy ( mathmatival compiutation)
#  pip install matplotlib (graphs and charts)
#  pip install seaborn ( graph and charts)
# pip install chart-studio ( interective charts)
# pip install cufflinks ( charts)
# pip install pandas-datareader ( helps in reading the data from various API's)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import datetime

# %%
from pandas_datareader import data,wb

# %% [markdown]
# Bank of America
#
# Citi group
#
# Goldman sachs
#
# Jpmorgan Chase
#
# Morgan Stanley

# %%
# creting a time line that i want to analyze the data of above global banks from year 2006 to year 2016
start = datetime.datetime(2006,1,1)
end = datetime.datetime(2016,1,1)

# %%
#Bank of america ( triger point is BAC and source is yahoo)
BAC=data.DataReader('BAC','yahoo',start,end)

# %%
BAC
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2006-01-03  47.180000  46.150002  46.919998  47.080002  16296700.0  33.777504
# 2006-01-04  47.240002  46.450001  47.000000  46.580002  17757900.0  33.418770
# 2006-01-05  46.830002  46.320000  46.580002  46.639999  14970700.0  33.461811
# 2006-01-06  46.910000  46.349998  46.799999  46.570000  12599800.0  33.411613
# 2006-01-09  46.970001  46.360001  46.720001  46.599998  15619400.0  33.433113
# ...               ...        ...        ...        ...         ...        ...
# 2015-12-24  17.379999  17.219999  17.320000  17.270000  29369400.0  15.281429
# 2015-12-28  17.230000  16.980000  17.219999  17.129999  41777500.0  15.157548
# 2015-12-29  17.350000  17.160000  17.250000  17.280001  45670400.0  15.290274
# 2015-12-30  17.240000  17.040001  17.200001  17.049999  35066400.0  15.086761
# 2015-12-31  17.070000  16.830000  17.010000  16.830000  47153000.0  14.892094
#
# [2517 rows x 6 columns]

# %%
BAC.head(5)
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2006-01-03  47.180000  46.150002  46.919998  47.080002  16296700.0  33.777504
# 2006-01-04  47.240002  46.450001  47.000000  46.580002  17757900.0  33.418770
# 2006-01-05  46.830002  46.320000  46.580002  46.639999  14970700.0  33.461811
# 2006-01-06  46.910000  46.349998  46.799999  46.570000  12599800.0  33.411613
# 2006-01-09  46.970001  46.360001  46.720001  46.599998  15619400.0  33.433113

# %%
BAC.tail()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2015-12-24  17.379999  17.219999  17.320000  17.270000  29369400.0  15.281429
# 2015-12-28  17.230000  16.980000  17.219999  17.129999  41777500.0  15.157548
# 2015-12-29  17.350000  17.160000  17.250000  17.280001  45670400.0  15.290274
# 2015-12-30  17.240000  17.040001  17.200001  17.049999  35066400.0  15.086761
# 2015-12-31  17.070000  16.830000  17.010000  16.830000  47153000.0  14.892094

# %%
# citi group
C=data.DataReader('C','yahoo',start,end)

# %%
C.head()
# Out:
#                   High         Low        Open       Close     Volume  \
# Date
# 2006-01-03  493.799988  481.100006  490.000000  492.899994  1537600.0
# 2006-01-04  491.000000  483.500000  488.600006  483.799988  1870960.0
# 2006-01-05  487.799988  484.000000  484.399994  486.200012  1143160.0
# 2006-01-06  489.000000  482.000000  488.799988  486.200012  1370210.0
# 2006-01-09  487.399994  483.000000  486.000000  483.899994  1680740.0
#
#              Adj Close
# Date
# 2006-01-03  361.662262
# 2006-01-04  354.984985
# 2006-01-05  356.746155
# 2006-01-06  356.746155
# 2006-01-09  355.058380

# %%
#Goldmansachs , jpmorgan chase ,Morgan stanley
GS=data.DataReader('GS','yahoo',start,end)
JPM=data.DataReader('JPM','yahoo',start,end)
MS=data.DataReader('MS','yahoo',start,end)

# %%
MS.head()
# Out:
#                  High        Low       Open      Close     Volume  Adj Close
# Date
# 2006-01-03  58.490002  56.740002  57.169998  58.310001  5377000.0  35.558960
# 2006-01-04  59.279999  58.349998  58.700001  58.349998  7977800.0  35.583347
# 2006-01-05  58.590000  58.020000  58.549999  58.509998  5778000.0  35.680931
# 2006-01-06  58.849998  58.049999  58.770000  58.570000  6889800.0  35.717522
# 2006-01-09  59.290001  58.619999  58.630001  59.189999  4144500.0  36.095615

# %%
tickers=['BAC','C','GS','JPM','MS']

# %%
# CONCATENATE
bank_stocks=pd.concat([BAC,C,GS,JPM,MS],axis=1,keys=tickers)
#axis=1 will concatenate according to columns

# %%
bank_stocks.head()
# Out:
#                   BAC                                                          \
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2006-01-03  47.180000  46.150002  46.919998  47.080002  16296700.0  33.777504
# 2006-01-04  47.240002  46.450001  47.000000  46.580002  17757900.0  33.418770
# 2006-01-05  46.830002  46.320000  46.580002  46.639999  14970700.0  33.461811
# 2006-01-06  46.910000  46.349998  46.799999  46.570000  12599800.0  33.411613
# 2006-01-09  46.970001  46.360001  46.720001  46.599998  15619400.0  33.433113
#
#                      C                                      ...        JPM  \
#                   High         Low        Open       Close  ...       Open
# Date                                                        ...
# 2006-01-03  493.799988  481.100006  490.000000  492.899994  ...  39.830002
# 2006-01-04  491.000000  483.500000  488.600006  483.799988  ...  39.779999
# ...

# %%
bank_stocks.columns.names=['Bank,Ticker','Stock info']

# %%
bank_stocks.head()
# Out:
# Bank,Ticker        BAC                                               \
# Stock info        High        Low       Open      Close      Volume
# Date
# 2006-01-03   47.180000  46.150002  46.919998  47.080002  16296700.0
# 2006-01-04   47.240002  46.450001  47.000000  46.580002  17757900.0
# 2006-01-05   46.830002  46.320000  46.580002  46.639999  14970700.0
# 2006-01-06   46.910000  46.349998  46.799999  46.570000  12599800.0
# 2006-01-09   46.970001  46.360001  46.720001  46.599998  15619400.0
#
# Bank,Ticker                      C                                      ...  \
# Stock info   Adj Close        High         Low        Open       Close  ...
# Date                                                                    ...
# 2006-01-03   33.777504  493.799988  481.100006  490.000000  492.899994  ...
# 2006-01-04   33.418770  491.000000  483.500000  488.600006  483.799988  ...
# 2006-01-05   33.461811  487.799988  484.000000  484.399994  486.200012  ...
# ...

# %% [markdown]
# # problem statements

# %% [markdown]
# **question 1 : what is the maximum close price for each back's stock throughout the time period**

# %%
bank_stocks['BAC']['Close'].max()
# Out:
# 54.900001525878906

# %%
# ONE RULE in Programming is DRY ' do not rpeat yourself'
# so we will create a d¨for loop

# %%
tickers
# Out:
# ['BAC', 'C', 'GS', 'JPM', 'MS']

# %%
# for loop for getting max clsoe price for all of the 5 banks at once
for i in tickers:
    print('The answer of',i,'is',bank_stocks[i]['Close'].max())
# Out:
# The answer of BAC is 54.900001525878906
# The answer of C is 564.0999755859375
# The answer of GS is 247.9199981689453
# The answer of JPM is 70.08000183105469
# The answer of MS is 89.30000305175781

# %%
# cross section
# cross section is used for multilevel indexing
bank_stocks.head()
# Out:
# Bank,Ticker        BAC                                               \
# Stock info        High        Low       Open      Close      Volume
# Date
# 2006-01-03   47.180000  46.150002  46.919998  47.080002  16296700.0
# 2006-01-04   47.240002  46.450001  47.000000  46.580002  17757900.0
# 2006-01-05   46.830002  46.320000  46.580002  46.639999  14970700.0
# 2006-01-06   46.910000  46.349998  46.799999  46.570000  12599800.0
# 2006-01-09   46.970001  46.360001  46.720001  46.599998  15619400.0
#
# Bank,Ticker                      C                                      ...  \
# Stock info   Adj Close        High         Low        Open       Close  ...
# Date                                                                    ...
# 2006-01-03   33.777504  493.799988  481.100006  490.000000  492.899994  ...
# 2006-01-04   33.418770  491.000000  483.500000  488.600006  483.799988  ...
# 2006-01-05   33.461811  487.799988  484.000000  484.399994  486.200012  ...
# ...

# %%
# we can extract max close price for all the banks using crossection
bank_stocks.xs(key='Close',axis=1,level='Stock info').max()
# Out:
# Bank,Ticker
# BAC     54.900002
# C      564.099976
# GS     247.919998
# JPM     70.080002
# MS      89.300003
# dtype: float64

# %% [markdown]
# **returns = (value at time t - value at time (t-1))/ value at time (t-1)**

# %%
returns=pd.DataFrame()

# %%
# for loop for getting return percentage for all of the banks
for i in tickers:
    returns[i  +  'return']=bank_stocks[i]['Close'].pct_change()

# %%
returns
# Out:
#             BACreturn   Creturn  GSreturn  JPMreturn  MSreturn
# Date
# 2006-01-03        NaN       NaN       NaN        NaN       NaN
# 2006-01-04  -0.010620 -0.018462 -0.013812  -0.014183  0.000686
# 2006-01-05   0.001288  0.004961 -0.000393   0.003029  0.002742
# 2006-01-06  -0.001501  0.000000  0.014169   0.007046  0.001025
# 2006-01-09   0.000644 -0.004731  0.012030   0.016242  0.010586
# ...               ...       ...       ...        ...       ...
# 2015-12-24  -0.004037  0.001520 -0.002624  -0.001948 -0.003681
# 2015-12-28  -0.008107 -0.006261 -0.004658  -0.003303 -0.009544
# 2015-12-29   0.008757  0.011455  0.010516   0.010395  0.011812
# 2015-12-30  -0.013310 -0.012835 -0.008282  -0.007157 -0.009831
# 2015-12-31  -0.012903 -0.010516 -0.009780  -0.008410 -0.013031
#
# [2517 rows x 5 columns]

# %% [markdown]
# **question: 2 which dates each banks has the best and worst single day returns**

# %%
# the worst date for each of the bank
returns.idxmin()
# Out:
# BACreturn   2009-01-20
# Creturn     2009-02-27
# GSreturn    2009-01-20
# JPMreturn   2009-01-20
# MSreturn    2008-10-09
# dtype: datetime64[ns]

# %%
# the best date for each of the bank
returns.idxmax()
# Out:
# BACreturn   2009-04-09
# Creturn     2008-11-24
# GSreturn    2008-11-24
# JPMreturn   2009-01-21
# MSreturn    2008-10-13
# dtype: datetime64[ns]

# %% [markdown]
# **question:3**
#
#    **a .Which stock would you classify as the riskiest during the entire time period**
#
#    **b.Which whould you classify as the riskiest during 2015**

# %%
# we need to see the standard deviation  of returns
returns.std()
# Out:
# BACreturn    0.036647
# Creturn      0.038672
# GSreturn     0.025390
# JPMreturn    0.027667
# MSreturn     0.037819
# dtype: float64

# %%
# above we can see that the citi bnak group is the riskiest since it has max standard deviation

# %%
# if i want to extract the index for most riskiest bank
returns.std().idxmax()
# Out:
# 'Creturn'

# %%
# extracting 2015 data from dataframe returns
returns.loc['2015-01-01':'2015-12-31']
# Out:
#             BACreturn   Creturn  GSreturn  JPMreturn  MSreturn
# Date
# 2015-01-02   0.000559  0.002772  0.002992  -0.001438 -0.002320
# 2015-01-05  -0.029050 -0.031515 -0.031223  -0.031045 -0.031258
# 2015-01-06  -0.029919 -0.035205 -0.020229  -0.025929 -0.028800
# 2015-01-07   0.004745  0.009270  0.014903   0.001526  0.014278
# 2015-01-08   0.020661  0.015048  0.015965   0.022346  0.014889
# ...               ...       ...       ...        ...       ...
# 2015-12-24  -0.004037  0.001520 -0.002624  -0.001948 -0.003681
# 2015-12-28  -0.008107 -0.006261 -0.004658  -0.003303 -0.009544
# 2015-12-29   0.008757  0.011455  0.010516   0.010395  0.011812
# 2015-12-30  -0.013310 -0.012835 -0.008282  -0.007157 -0.009831
# 2015-12-31  -0.012903 -0.010516 -0.009780  -0.008410 -0.013031
#
# [252 rows x 5 columns]

# %%
# riskiest in year 2015
returns.loc['2015-01-01':'2015-12-31'].std().idxmax()
# Out:
# 'MSreturn'

# %% [markdown]
# # Data Visualization

# %% [markdown]
# **creating a distribution plot for Morgan Stanley**

# %%
y=returns.loc['2015-01-01':'2015-12-31']

# %%
y.head()
# Out:
#             BACreturn   Creturn  GSreturn  JPMreturn  MSreturn
# Date
# 2015-01-02   0.000559  0.002772  0.002992  -0.001438 -0.002320
# 2015-01-05  -0.029050 -0.031515 -0.031223  -0.031045 -0.031258
# 2015-01-06  -0.029919 -0.035205 -0.020229  -0.025929 -0.028800
# 2015-01-07   0.004745  0.009270  0.014903   0.001526  0.014278
# 2015-01-08   0.020661  0.015048  0.015965   0.022346  0.014889

# %%
sns.displot(y['MSreturn'],kde=True,color='green',bins=30)

# %%
# above we can see that its a normal distribution

# %% [markdown]
# **creating a distribution plot for year 2008 returns of citibank group**

# %%
z=returns.loc['2008-01-01':'2008-12-31']

# %%
sns.displot(z['Creturn'],kde=True,color='purple',bins=30)

# %%
# above plot we can see that the variabilty of returns for citigroup banks varies from -20% to 60 % wheresas for Morgan stanley 
# it varies from -6% to 6% so it is agin showing our analysis which we have done earlier that citibank group is the riskiest

# %% [markdown]
# # **interactive plotting**

# %%
import cufflinks as cf
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot
init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.4.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.4.2.min']
#             }
#         });
# ...

# %%
for i in tickers:
    bank_stocks[i]['Close'].plot(label=i,figsize=(12,6))
    plt.legend()

# %%
# instead of using loop we can also use cross section
bank_stocks.xs(key='Close',axis=1,level='Stock info').plot(figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # interactive ploting

# %%
bank_stocks.xs(key='Close',axis=1,level='Stock info').iplot()
# Out:
# <div>                            <div id="da638dae-0b98-483b-b92f-7fbaca9e467b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# **moving averages**

# %%
plt.figure(figsize=(12,4))
#it will create a blank figure or chart
BAC['Close'].loc['2008-01-01':'2008-12-31'].rolling(window=30).mean().plot(label= '30 Day moving avearge')
BAC['Close'].loc['2008-01-01':'2008-12-31'].plot(label='BAC Close price')
plt.legend()

# %% [markdown]
# **Heatmap**

# %%
#correlation
bank_stocks.xs(key='Close',axis=1,level='Stock info').corr()
# Out:
# Bank,Ticker       BAC         C        GS       JPM        MS
# Bank,Ticker
# BAC          1.000000  0.971516  0.550898  0.103874  0.944218
# C            0.971516  1.000000  0.434123  0.003515  0.933609
# GS           0.550898  0.434123  1.000000  0.685286  0.683792
# JPM          0.103874  0.003515  0.685286  1.000000  0.250427
# MS           0.944218  0.933609  0.683792  0.250427  1.000000

# %%
sns.heatmap(bank_stocks.xs(key='Close',axis=1,level='Stock info').corr(),annot=True)
# Out:
# <AxesSubplot:xlabel='Bank,Ticker', ylabel='Bank,Ticker'>

# %%
# interactive heatmap
close_c=bank_stocks.xs(key='Close',axis=1,level='Stock info').corr()

# %%
close_c.iplot(kind='heatmap',colorscale='rdylbu')
# Out:
# <div>                            <div id="f63c8d59-179f-4c7c-b7f7-08fa9cc04fee" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
# candelstick charts 
BAC.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2006-01-03  47.180000  46.150002  46.919998  47.080002  16296700.0  33.777504
# 2006-01-04  47.240002  46.450001  47.000000  46.580002  17757900.0  33.418770
# 2006-01-05  46.830002  46.320000  46.580002  46.639999  14970700.0  33.461811
# 2006-01-06  46.910000  46.349998  46.799999  46.570000  12599800.0  33.411613
# 2006-01-09  46.970001  46.360001  46.720001  46.599998  15619400.0  33.433113

# %%
 bac_2015=BAC[['Open','High','Low','Close']].loc['2015-01-01':'2015-12-31']

# %%
bac_2015.iplot(kind='candle')
# Out:
# <div>                            <div id="bbe7fc38-5662-4402-9cad-b2b9bcb7182a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
